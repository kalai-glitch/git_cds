# %% [markdown]
# <a href="https://colab.research.google.com/github/kalai-glitch/git_cds/blob/main/Pandaspra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import basic libraries
import numpy as np
import pandas as pd

# %%
a=pd.Series() #creating empty series
print(a)
# Out:
# Series([], dtype: object)

# %%
b=pd.Series("hello")
print(b)
# Out:
# 0    hello
# dtype: object

# %%
list=["red","blue","orange"]
c=pd.Series(list)
print(c)
# Out:
# 0       red
# 1      blue
# 2    orange
# dtype: object

# %%
tuple=(3,4,5,6)
d=pd.Series(tuple)
print(d)
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# dtype: int64

# %%
dict={101:"car",102:"bike",103:"scooty"} #craeting dictionary using key:values
sale=pd.Series(dict)
print(sale)
# Out:
# 101       car
# 102      bike
# 103    scooty
# dtype: object

# %%
import pandas as pd

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.Series(mydataset)
v=pd.DataFrame(mydataset)

print(v)
print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2
# cars        [BMW, Volvo, Ford]
# passings             [3, 7, 2]
# dtype: object

# %%
a=pd.Series(["monday","tuesday","wed","thursday"])
print(a)
# Out:
# 0      monday
# 1     tuesday
# 2         wed
# 3    thursday
# dtype: object

# %%
a.index=["day 1","day 2","day 3",'day 4'] #change index value as u want
print(a)
# Out:
# day 1      monday
# day 2     tuesday
# day 3         wed
# day 4    thursday
# dtype: object

# %%
a[1]
# Out:
# /tmp/ipython-input-37-240059899.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   a[1]
# 'tuesday'

# %%
a['day 2']
# Out:
# 'tuesday'

# %% [markdown]
# DATAFRAME

# %%
#SYNTAX
#pd.DataFrame(data,index,column)

# %%
list_2d=[[3,2,1],[2,3,4],[4,5,6]]
a=pd.DataFrame(list_2d)
print(a)
# Out:
#    0  1  2
# 0  3  2  1
# 1  2  3  4
# 2  4  5  6

# %%
data=[["john",40],["kalai",30],["sheela",20]]
name=pd.DataFrame(data,columns=["Name","age"],index=[10,11,12])
name
# Out:
#       Name  age
# 10    john   40
# 11   kalai   30
# 12  sheela   20

# %%
#creating dataframe using dictionary
dict1={"Name":["john","gayu","kalai","venu"],"Age":[57,35,30,56],"Job":["HR","Manager","lead","assistant"],"Salary":[20000,60000,40000,20000]}
data1=pd.DataFrame(dict1,index=[10,11,12,14])
print(data1)
# Out:
#      Name  Age        Job  Salary
# 10   john   57         HR   20000
# 11   gayu   35    Manager   60000
# 12  kalai   30       lead   40000
# 14   venu   56  assistant   20000

# %%
data1.sort_values("Salary",ascending=False) #to change in descending use ascending =false, to change peemanently inplace =true
# Out:
#      Name  Age        Job  Salary
# 11   gayu   35    Manager   60000
# 12  kalai   30       lead   40000
# 10   john   57         HR   20000
# 14   venu   56  assistant   20000

# %%
data=data1.copy()
data
# Out:
#      Name  Age        Job  Salary
# 11   gayu   35    Manager   60000
# 12  kalai   30       lead   40000
# 10   john   57         HR   20000
# 14   venu   56  assistant   20000

# %%
#loc function used to fetch column and row using column name or index name
#iloc fetch column and row by index position
#fecth name column
data1[["Name"]]
# Out:
#      Name
# 11   gayu
# 12  kalai
# 10   john
# 14   venu

# %%
data1[["Age","Salary"]]
# Out:
#     Age  Salary
# 11   35   60000
# 12   30   40000
# 10   57   20000
# 14   56   20000

# %%
data1.loc[:,"Name"] #syntax variable name.loc[r,c]
# Out:
# 11     gayu
# 12    kalai
# 10     john
# 14     venu
# Name: Name, dtype: object

# %%
data1.loc[:,"Age"]
# Out:
# 11    35
# 12    30
# 10    57
# 14    56
# Name: Age, dtype: int64

# %%
data1.loc[:,["Age","Salary"]]
# Out:
#     Age  Salary
# 11   35   60000
# 12   30   40000
# 10   57   20000
# 14   56   20000

# %%
data1.loc[11,:]
# Out:
# Name         gayu
# Age            35
# Job       Manager
# Salary      60000
# Name: 11, dtype: object

# %%
data1.loc[[11,12],:]
# Out:
#      Name  Age      Job  Salary
# 11   gayu   35  Manager   60000
# 12  kalai   30     lead   40000

# %%
data1.loc[11:14,:] #or data1.loc[[11,12,13,14],:]
# Out:
#      Name  Age        Job  Salary
# 11   gayu   35    Manager   60000
# 12  kalai   30       lead   40000
# 10   john   57         HR   20000
# 14   venu   56  assistant   20000

# %%
data1.loc[[11,12],["Name","Age"]]
# Out:
#      Name  Age
# 11   gayu   35
# 12  kalai   30

# %%
data1.loc[:,["Age","Job","Salary"]]
# Out:
#     Age        Job  Salary
# 11   35    Manager   60000
# 12   30       lead   40000
# 10   57         HR   20000
# 14   56  assistant   20000

# %%
#iloc
data1.iloc[:,0]
# Out:
# 11     gayu
# 12    kalai
# 10     john
# 14     venu
# Name: Name, dtype: object

# %%
data1.iloc[:,[2,3]]
# Out:
#           Job  Salary
# 11    Manager   60000
# 12       lead   40000
# 10         HR   20000
# 14  assistant   20000

# %%
data1.iloc[1:4,0:3]
# Out:
#      Name  Age        Job
# 12  kalai   30       lead
# 10   john   57         HR
# 14   venu   56  assistant
